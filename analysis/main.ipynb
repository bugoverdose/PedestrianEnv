# %%
from dqn import run_DQN

# before VecNormalize
run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256], learning_rate=5e-4)
# Out:
# net_arch [256, 256, 256]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0005
# n_eval_episodes 20
# total_timesteps 50000
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./tb_logs/dqn_18
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4839     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 8        |
# ...

# %%
from dqn import run_DQN

# after VecNormalize
# run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256], learning_rate=5e-4, tb_log_name="dqn_tuning") # -4XX
# run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -3XX
run_DQN(total_timesteps=100_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -527
# Out:
# net_arch [256, 256, 256]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0001
# n_eval_episodes 20
# total_timesteps 100000
# Using cpu device
# Logging to ./tb_logs/dqn_tuning_5
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3697     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4353     |
# ...
