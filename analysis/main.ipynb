# %%
from dqn import run_DQN

run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256])
# Out:
# net_arch [256, 256, 256]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0005
# n_eval_episodes 20
# total_timesteps 50000
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./tb_logs/dqn_18
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4839     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 8        |
# ...

# %%
from dqn import run_DQN

run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256, 256])
# Out:
# net_arch [256, 256, 256, 256]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0005
# n_eval_episodes 20
# total_timesteps 50000
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./tb_logs/dqn_20
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4611     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 8        |
# ...

# %%
from dqn import run_DQN

run_DQN(total_timesteps=50_000, net_arch=[512, 512, 512])
# Out:
# net_arch [512, 512, 512]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0005
# n_eval_episodes 20
# total_timesteps 50000
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./tb_logs/dqn_19
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4585     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 8        |
# ...

# %%
from dqn import run_DQN

run_DQN(total_timesteps=500_000, net_arch=[256, 256, 256])
# Out:
# net_arch [256, 256, 256]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0005
# n_eval_episodes 20
# total_timesteps 500000
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./tb_logs/dqn_21
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3904     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 8        |
# ...
