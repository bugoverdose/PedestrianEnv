# %%
from dqn import run_DQN

# VecNormalize + fix crosswalk obs + max penalty if not known
# run_DQN(total_timesteps=200_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -97.000
run_DQN(total_timesteps=200_000, net_arch=[256, 256, 256], learning_rate=5e-4, tb_log_name="dqn_tuning") # -259.5000
# Out:
# net_arch [256, 256, 256]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0005
# n_eval_episodes 20
# total_timesteps 200000
# Using cpu device
# Logging to ./tb_logs/dqn_tuning_6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3581     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4517     |
# ...

# %%
from dqn import run_DQN

# VecNormalize + fix crosswalk obs
run_DQN(total_timesteps=200_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -65.0000
