# %%
from dqn import run_DQN

# Logging to ./tb_logs/dqn_tuning_17
# run_DQN(total_timesteps=200_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -160
# run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -412.5
# run_DQN(total_timesteps=50_000, net_arch=[256, 256, 256], learning_rate=5e-4, tb_log_name="dqn_tuning") # -301

# %%
from dqn import run_DQN

# Logging to ./tb_logs/dqn_tuning_18
# run_DQN(total_timesteps=500_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -274.5 (but reached -50)

# ./tb_logs/dqn_tuning_20
# run_DQN(seed=1000, total_timesteps=1_000_000, net_arch=[256, 256, 256], learning_rate=1e-4, tb_log_name="dqn_tuning") # -460

# %%
from dqn import run_DQN

# Logging to ./tb_logs/dqn_512_3_tuning_3
# run_DQN(total_timesteps=100_000, net_arch=[512, 512, 512], learning_rate=1e-4, tb_log_name="dqn_512_3_tuning") # -362

# Logging to ./tb_logs/dqn_512_3_tuning_4
# run_DQN(seed=42, total_timesteps=500_000, net_arch=[512, 512, 512], learning_rate=1e-4, tb_log_name="dqn_512_3_tuning") # -360
# Out:
# net_arch [512, 512, 512]
# target_update_interval 500
# buffer_size 10000
# learning_starts 2000
# train_freq 1
# exploration_fraction 0.6
# exploration_final_eps 0.05
# learning_rate 0.0001
# n_eval_episodes 20
# total_timesteps 500000
# Using cpu device
# Logging to ./tb_logs/dqn_512_3_tuning_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -495     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4240     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 8        |
# ...
